# %%
import matplotlib. pyplot as plt
import numpy as np
import math
import pandas as pd
import os,sys
import glob

# %% [markdown]
# folder = '/home/echeveste/Mis_trabajos/analisis_datos/beatles/chordlab/The_Beatles/12_-_Let_It_Be/'
# for filename in os.listdir(folder):
#        infilename = os.path.join(folder,filename)
#        if not os.path.isfile(infilename): continue
#        oldbase = os.path.splitext(filename)
#        newname = infilename.replace('.lab', '.csv')
#        output = os.rename(infilename, newname)

# %%
folder = '/home/echeveste/Mis_trabajos/analisis_datos/beatles/chordlab/The_Beatles/'
for album in os.listdir(folder):
    album_path = os.path.join(folder,album)
    for song in os.listdir(album_path):
        print(song)
        p = pd.read_csv(os.path.join(album_path,song), sep=' ') 
        print(p)
        #infilename = os.path.join(album_path,song)
        #if not os.path.isfile(infilename): continue
        #oldbase = os.path.splitext(filename)
        #newname = infilename.replace('.lab', '.csv')
        #output = os.rename(infilename, newname)
# Out:
# 04_-_Love_You_To.csv
#       0.000000    0.440395           N
# 0     0.440395    4.959231           N
# 1     4.959231   35.834761  C:min(*b3)
# 2    35.834761   58.265238  C:min(*b3)
# 3    58.265238   59.721399          Bb
# 4    59.721399   60.238385  C:min(*b3)
# 5    60.238385   61.608911          Bb
# 6    61.608911   62.142970  C:min(*b3)
# 7    62.142970   63.478117          Bb
# 8    63.478117   63.977346  C:min(*b3)
# 9    63.977346   65.370544          Bb
# 10   65.370544   88.277029  C:min(*b3)
# 11   88.277029   89.716666          Bb
# 12   89.716666   90.300134  C:min(*b3)
# 13   90.300134   91.609092          Bb
# 14   91.609092   92.143151  C:min(*b3)
# 15   92.143151   93.478299          Bb
# 16   93.478299   94.023968  C:min(*b3)
# 17   94.023968   95.370725          Bb
# 18   95.370725  114.904815  C:min(*b3)
# 19  114.904815  116.338344          Bb
# 20  116.338344  116.884013  C:min(*b3)
# 21  116.884013  118.253990          Bb
# ...

# %%
path = '/home/echeveste/Mis_trabajos/analisis_datos/beatles/chordlab/The_Beatles/'
extension = 'csv'
os.chdir(path)
result = glob.glob('*.{}'.format(extension))
print(result)
# Out:
# ["13_-_There's_A_Place.csv", '04_-_Chains.csv', '07_-_Please_Please_Me.csv', '08_-_Love_Me_Do.csv', '09_-_P._S._I_Love_You.csv', '03_-_Anna_(Go_To_Him).csv', '01_-_I_Saw_Her_Standing_There.csv', '06_-_Ask_Me_Why.csv', '02_-_Misery.csv', '12_-_A_Taste_Of_Honey.csv', '05_-_Boys.csv', "10_-_Baby_It's_You.csv", '11_-_Do_You_Want_To_Know_A_Secret.csv', '14_-_Twist_And_Shout.csv']

# %%
p = pd.read_csv('/home/echeveste/Mis_trabajos/analisis_datos/beatles/chordlab/The_Beatles/01_Please_Please_Me/02_-_Misery.csv', sep=' ')

# %%
p
# Out:
#       0.000000    0.440395           N
# 0     0.440395    4.959231           N
# 1     4.959231   35.834761  C:min(*b3)
# 2    35.834761   58.265238  C:min(*b3)
# 3    58.265238   59.721399          Bb
# 4    59.721399   60.238385  C:min(*b3)
# 5    60.238385   61.608911          Bb
# 6    61.608911   62.142970  C:min(*b3)
# 7    62.142970   63.478117          Bb
# 8    63.478117   63.977346  C:min(*b3)
# 9    63.977346   65.370544          Bb
# 10   65.370544   88.277029  C:min(*b3)
# 11   88.277029   89.716666          Bb
# 12   89.716666   90.300134  C:min(*b3)
# 13   90.300134   91.609092          Bb
# 14   91.609092   92.143151  C:min(*b3)
# 15   92.143151   93.478299          Bb
# 16   93.478299   94.023968  C:min(*b3)
# 17   94.023968   95.370725          Bb
# 18   95.370725  114.904815  C:min(*b3)
# 19  114.904815  116.338344          Bb
# 20  116.338344  116.884013  C:min(*b3)
# 21  116.884013  118.253990          Bb
# 22  118.253990  118.799659  C:min(*b3)
# ...

# %%
from pychord import Chord
#Chord(p.N[2]).components()

# %%
Chord('Ebsus4').components()
# Out:
# ['Eb', 'Ab', 'Bb']

# %%
Chord('Fm6').components()
# Out:
# ['F', 'Ab', 'C', 'D']
