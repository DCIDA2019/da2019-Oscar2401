# %%
import numpy as np
import math as mt
import matplotlib.pyplot as plt
import scipy 
from scipy.integrate import trapz,simps

from colossus.cosmology import cosmology

# %%
def model(Om,b2,k,z=0.57):
    cosmo = cosmology.setCosmology('planck15',)
    cosmo.Om0 = Om
    return b2**2*cosmo.matterPowerSpectrum(k,z) #función

# %%
#Funcion para calcular la chi cuadrada con otro parametro f
def chisq_2(theta,data):
    om, b2 = theta
    #Nuestros datos
    x, y, yerr = data
    sigma2 = yerr**2 
    #Sumamos para encontrar el logaritmo del likelihood
    return -0.5*np.sum((y-model(om,b2,x,z=0.57))**2/sigma2 + np.log(sigma2))

# %%
# Prior
def log_prior(theta):
    om, b2 = theta
    if 0.05 < om < 1.0 and 0.05 < b2 < 5.0:
        return 0.0
    return -np.inf

# %%
def metrop_2(om_ini,b_ini,data,sigm,ite):
    np.random.seed(1)
    #Reordenamos el arreglo de a y b iniciales.
    om_ini = om_ini.T.reshape((len(om_ini),1))
    b_ini = b_ini.T.reshape((len(b_ini),1))
    #f_ini = f_ini.T.reshape((len(f_ini),1))
    data = np.array(data)
    
    ch_ini = [] #iniciamos lista para los valores de chi iniciales.
    
    #Llenamos chi_ini con los valores iniciales 
    for i in range(len(om_ini)):
        ch_ini.append(chisq_2([om_ini[i][0],b_ini[i][0]],data)+ log_prior([om_ini[i][0],b_ini[i][0]])) #prior
    
    #Transformamos a_ini de array a list para usar la función append.
    om = om_ini.tolist()
    b = b_ini.tolist()
    
    for i in range(len(om_ini)):
        ch_0 = ch_ini[i] 
        k = 0
        for j in range(ite): 
            om_af = np.random.normal(om[i][k],sigm) #creamos un valor de a y b aleatorios
            b_af = np.random.normal(b[i][k],sigm) #calculamos el logaritmo del likelihood de para los parametros aleatorios
            #f_af = np.random.normal(f[i][k],sigm) 
            
            lg = log_prior([om_af,b_af])
            
            if lg != 0:
                ch = lg
            else:
                ch = chisq_2([om_af,b_af],data) + lg
            
            if ch > ch_0: #Comparamos las dos dos logaritmos 
                om[i].append(om_af) #guardamos los parametros creados 
                b[i].append(b_af)
                #f[i].append(f_af)
                k = k+1
                ch_0 = ch # si el nuevo logaritmo es es mayor que el anterior lo tomamos como el nuevo
            else:
                r = np.log(np.random.uniform(0,1)) 
                diff = ch-ch_0
                if diff > r: #Si la diferencia entre los logaritmos (anterior y nuevo) es menor al dicho valor
                    om[i].append(om_af)
                    b[i].append(b_af)
                    #f[i].append(f_af)
                    k = k+1
                    ch_0 = ch #Tomamos el nuevo logaritmo
                else:  #si la direfencia es mayor, sólo guardamos los valores de a y b creados
                    om[i].append(om[i][k]) 
                    b[i].append(b[i][k])
                    #f[i].append(f[i][k])
                    k = k+1
            

    # Parte de grafico
    plt.figure(figsize=(8,6))    
    
    #Gráfica de todos los puntos
    for i in range(len(om_ini)):     
        plt.scatter(om[i],b[i],s=1)
    plt.ylabel('b',fontsize=18)
    plt.xlabel('$\Omega_m$',fontsize=18)
    plt.title("Varios Caminadores",fontsize=18)
    return  om, b

# %%
#Función para solo tomar el cumulo de los caminadores y graficarlos con sus histograma
def flags_data_1(a,b,flags):
    a_flg = np.array([])
    b_flg = np.array([])
    for i in range(len(a)): 
        a_flg = np.append(a_flg,a[i][flags:]) #Solo tomamos los valores de los parametros por arriba del número flags 
        b_flg = np.append(b_flg,b[i][flags:])
    
    flgs = np.array([a_flg,b_flg])
    n = len(flgs)
    m = []
    mp = []
    titulo = ['Histograma de $\Omega_m$', 'Histograma de b']
    
    #Sección para graficar:
    plt.figure(figsize=(10,10))  
    for i in range(n):
        for j in range(i+1):
            k = i-j
            if i == k:
                plt.subplot(n,n,((i*n)+k+1))
                hist = plt.hist(flgs[k], bins=20,facecolor='grey',alpha = 0.8)
                m.append(np.mean(hist[1]))
                mp.append(np.mean(hist[1]))
                plt.axvline(m[i],color='r',label = np.round(m[i],4))
                plt.title(titulo[i],fontsize=18)
                plt.legend();
            else:
                plt.subplot(n,n,((i*n)+k+1))
                plt.hexbin(flgs[k], flgs[i], gridsize=30, cmap='Greys')
                plt.axvline(m[k],color='r',label = np.round(m[k],4))
                plt.axhline(m[i],color='b',label = np.round(m[i],4))
                plt.legend();
    
    return a_flg , b_flg, m

# %% [markdown]
# #### Mostramos los datos

# %%
pk_cmasdr12 = np.loadtxt('GilMarin_boss_data/post-recon/cmass/GilMarin_2016_CMASSDR12_measurement_monopole_post_recon.txt').T

plt.figure()
plt.loglog()
plt.errorbar(pk_cmasdr12[0],pk_cmasdr12[1],yerr=pk_cmasdr12[2],fmt='.')
plt.xlim(1e-3,1)
plt.ylim(100,3e5)
# Out:
# (100, 300000.0)

# %% [markdown]
# #### Eliminamos los primeros y ultimos puntos

# %%
li = 20
ls = len(pk_cmasdr12[0])-10
k, pk, pk_err = pk_cmasdr12[0][li:ls],pk_cmasdr12[1][li:ls],pk_cmasdr12[2][li:ls]

plt.figure()
plt.loglog()
plt.errorbar(k,pk,yerr = pk_err,fmt='.')
plt.xlim(1e-3,0.8)
plt.ylim(1500,3e5)
# Out:
# (1500, 300000.0)

# %%
cosmo = cosmology.setCosmology('planck15',)

data = [k,pk,pk_err]

sigma = 0.1
om_ini = np.array([0.3,0.2,0.4])
b_ini = np.array([0.5,0.1,0.6])
ite = 40000

om_2,b_2= metrop_2(om_ini,b_ini,data,sigma,ite)
# Out:
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-9-c59749f9b630> in <module>()
#       8 ite = 40000
#       9
# ---> 10 om_2,b_2= metrop_2(om_ini,b_ini,data,sigma,ite)
#
# <ipython-input-5-c5184f2669b8> in metrop_2(om_ini, b_ini, data, sigm, ite)
#      30                 ch = lg
#      31             else:
# ---> 32                 ch = chisq_2([om_af,b_af],data) + lg
#      33
#      34             if ch > ch_0: #Comparamos las dos dos logaritmos
#
# <ipython-input-3-6d52e557921b> in chisq_2(theta, data)
#       6     sigma2 = yerr**2
#       7     #Sumamos para encontrar el logaritmo del likelihood
# ----> 8     return -0.5*np.sum((y-model(om,b2,x,z=0.57))**2/sigma2 + np.log(sigma2))
#
# <ipython-input-2-183e7a441eac> in model(Om, b2, k, z)
#       2     cosmo = cosmology.setCosmology('planck15',)
#       3     cosmo.Om0 = Om
# ----> 4     return b2**2*cosmo.matterPowerSpectrum(k,z) #función
#
# /usr/local/lib/python3.6/dist-packages/colossus/cosmology/cosmology.py in matterPowerSpectrum(self, k, z, model, path, derivative)
#    2096 												ignore_norm = False)
#    2097
# -> 2098                 Pk *= self.growthFactor(z)**2
#    2099
#    2100                 return Pk
#
# /usr/local/lib/python3.6/dist-packages/colossus/cosmology/cosmology.py in growthFactor(self, z, derivative, inverse)
#    1823                 else:
#    1824 			D = self._zFunction('lnzp1_growthfactor', self._growthFactorExact, z, derivative = derivative,
# -> 1825 						inverse = inverse)
#    1826
#    1827                 return D
#
# /usr/local/lib/python3.6/dist-packages/colossus/cosmology/cosmology.py in _zFunction(self, table_name, func, z, inverse, future, derivative)
#     877
#     878                         # Get interpolator. If it does not exist, create it.
# --> 879                         interpolator = self._zInterpolator(table_name, func, inverse = inverse, future = future)
#     880
#     881                         # Check limits of z array. If inverse == True, we need to check the limits on
#
# /usr/local/lib/python3.6/dist-packages/colossus/cosmology/cosmology.py in _zInterpolator(self, table_name, func, inverse, future)
#     851                         zp1_log_table = np.linspace(log_min, log_max, self.z_Nbins)
#     852                         z_table = np.exp(zp1_log_table) - 1.0
# --> 853                         x_table = func(z_table)
#     854
#     855                         self.storageUser.storeObject(table_name, np.array([zp1_log_table, x_table]))
#
# /usr/local/lib/python3.6/dist-packages/colossus/cosmology/cosmology.py in _growthFactorExact(self, z)
#    1780         def _growthFactorExact(self, z):
#    1781
# -> 1782                 D = self.growthFactorUnnormalized(z) / self.growthFactorUnnormalized(0.0)
#    1783
#    1784                 return D
#
# /usr/local/lib/python3.6/dist-packages/colossus/cosmology/cosmology.py in growthFactorUnnormalized(self, z)
#    1748                 z1 = z_arr[mask1]
#    1749                 if self.de_model == 'lambda':
# -> 1750                         D[mask1] = 5.0 / 2.0 * self.Om0 * Ez_D(z1) * self._integral(integrand, z1, np.inf)
#    1751                 else:
#    1752                         if np.count_nonzero(mask1) > 0:
#
# /usr/local/lib/python3.6/dist-packages/colossus/cosmology/cosmology.py in _integral(self, integrand, z_min, z_max)
#     803                         integ = np.zeros_like(z_min_use)
#     804                         for i in range(len(z_min_use)):
# --> 805                                 integ[i], _ = scipy.integrate.quad(integrand, z_min_use[i], z_max_use[i])
#     806                 else:
#     807                         integ, _ = scipy.integrate.quad(integrand, z_min, z_max)
#
# /usr/local/lib/python3.6/dist-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /usr/local/lib/python3.6/dist-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
# --> 450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     451     else:
#     452         if infbounds != 0:
#
# /usr/local/lib/python3.6/dist-packages/colossus/cosmology/cosmology.py in integrand(z)
#    1676
#    1677                 def integrand(z):
# -> 1678                         return (1.0 + z) / (Ez_D(z))**3
#    1679
#    1680                 # -----------------------------------------------------------------------------------------
#
# KeyboardInterrupt:

# %%
flags = 2000
omg_flg,b_flg, m = flags_data_1(om_2,b_2,flags)

# %%
k_m = 10**np.linspace(-6,5,100000)
pk_m = model(m[0],m[1],k_m,z=0.57)

plt.figure()
plt.loglog()
plt.errorbar(k,pk,yerr = pk_err,fmt='.')
plt.plot(k_m,pk_m,'-')
plt.xlim(1e-3,0.8)
plt.ylim(1500,3e5)
# Out:
# (1500, 300000.0)

# %% [markdown]
# Checa la Página Tutorial:
# https://bdiemer.bitbucket.io/colossus/_static/tutorial_cosmology.html

# %%
cosmo = cosmology.setCosmology('planck15',) #Se seleccionan el tranajo de planck
print(cosmo)
# Out:
# Cosmology "planck15"
#     flat = True, Om0 = 0.3089, Ode0 = 0.6910, Ob0 = 0.0486, H0 = 67.74, sigma8 = 0.8159, ns = 0.9667
#     de_model = lambda, relspecies = True, Tcmb0 = 2.7255, Neff = 3.0460, powerlaw = False

# %%
#Cambiamos los parametros para seleccionar la cosmologia
cosmo.Om0 = 0.29
cosmo.Omde = 0.71
cosmo.ns = 0.97
cosmo.H0 = 70
cosmo.relspecies  = False
cosmo.checkForChangedCosmology()
print(cosmo)
# Out:
# Cosmology: Detected change in cosmological parameters.
# Cosmology "planck15"
#     flat = True, Om0 = 0.2900, Ode0 = 0.7100, Ob0 = 0.0486, H0 = 70.00, sigma8 = 0.8159, ns = 0.9700
#     de_model = lambda, relspecies = False, Tcmb0 = 2.7255, Neff = 3.0460, powerlaw = False

# %%
k = 10**np.linspace(-6,5,100000)
Pk = cosmo.matterPowerSpectrum(k,0.57) #Redshft = 0.57

plt.figure()
plt.loglog()
plt.xlabel('k(Mpc/c)')
plt.ylabel('P(k)')
plt.plot(k,Pk)

# %% [markdown]
# Para descargar datos: http://www.sdss3.org/science/boss_publications.php

# %%
pk_cmasdr12 = np.loadtxt('GilMarin_boss_data/post-recon/cmass/GilMarin_2016_CMASSDR12_measurement_monopole_post_recon.txt').T

plt.figure()
plt.loglog()
plt.errorbar(pk_cmasdr12[0],pk_cmasdr12[1],yerr=pk_cmasdr12[2],fmt='.')
plt.plot(k,1.85**2*Pk,'-')
plt.xlim(1e-3,1)
plt.ylim(100,3e5)
# Out:
# (100, 300000.0)

# %%
cosmo = cosmology.setCosmology('planck15',) #Se inicia la clase de nuevo
print(cosmo)

def Pk_Om(Om,b2,k,z=0.57):
    cosmo.Om0 = Om
    return b2**2*cosmo.matterPowerSpectrum(k,z) #función
# Out:
# Cosmology "planck15"
#     flat = True, Om0 = 0.3089, Ode0 = 0.6910, Ob0 = 0.0486, H0 = 67.74, sigma8 = 0.8159, ns = 0.9667
#     de_model = lambda, relspecies = True, Tcmb0 = 2.7255, Neff = 3.0460, powerlaw = False

# %%
plt.figure()
plt.loglog()
#plt.errorbar(pk_cmasdr12[0],pk_cmasdr12[1],yerr=pk_cmasdr12[2],fmt='.')
OM = (0.2,0.3,0.4)
for om in OM:
    plt.plot(k,1.85**2*Pk_Om(om,1.85,k),'-')
    plt.plot(k,1.85**2*Pk_Om(om,3,k),'--')
    plt.xlim(1e-3,1)
    plt.ylim(100,1e7)
